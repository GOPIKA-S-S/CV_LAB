# %% [markdown]
# <a href="https://colab.research.google.com/github/GOPIKA-S-S/CV_LAB/blob/main/CV_LAB10_2348518.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# Loading the video
video_path = "/content/WhatsApp Video 2024-04-23 at 23.49.28_999c39a7.mp4"
cam = cv2.VideoCapture(video_path)

# Getting the frame rate of the video
fps = cam.get(cv2.CAP_PROP_FPS)

# Calculating the number of frames to skip for 1 second interval
skip_frames = int(fps)

frame_no = 0

# %%
# Reading the frames
while (True):
    ret, frame = cam.read()

    if ret:
        frame_no += 1
        if frame_no % skip_frames == 0:
            # Extracting the color components
            b, g, r = cv2.split(frame)
            print(f"Frame Number: {frame_no}")
            print(f"Frame Shape: {frame.shape}")
            print(f"Color Components are as follows:\nRed - {np.mean(r):.2f}\nGreen - {np.mean(g):.2f}\nBlue - {np.mean(b):.2f}")
            plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
            plt.show()
    else:
        break

cam.release()
# Out:
# Frame Number: 10
# Frame Shape: (238, 320, 3)
# Color Components are as follows:
# Red - 129.14
# Green - 114.96
# Blue - 114.01
