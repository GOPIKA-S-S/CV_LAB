# %% [markdown]
# <a href="https://colab.research.google.com/github/GOPIKA-S-S/CV_LAB/blob/main/2348518_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Load the input image
input_image = cv2.imread('/content/img1.jpg')

# Define the affine transformation matrix
# For example, to perform a translation, you can define the matrix like this:
M = np.float32([[1, 2, 100],
                [2, 1, 50]])

# Get the height and width of the input image
height, width = input_image.shape[:2]

# Perform the affine transformation
output_image = cv2.warpAffine(input_image, M, (width, height))

# Display the input and output images
print("Original image")
cv2_imshow(input_image)
cv2_imshow(output_image)
# Out:
# Original image
# <PIL.Image.Image image mode=RGB size=1920x1080>
# <PIL.Image.Image image mode=RGB size=1920x1080>
